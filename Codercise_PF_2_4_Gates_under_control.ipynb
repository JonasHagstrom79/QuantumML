# %%
# !pip install pennylane
import pennylane as qml
import numpy as np
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.3/57.3 kB 1.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 28.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 935.6/935.6 kB 23.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 167.9/167.9 kB 7.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 80.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 101.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 73.6 MB/s eta 0:00:00
# ...

# %% [markdown]
# ![PennyLane8.png](data:image/png;base64,...)

# %% [markdown]
# ![PennyLane9.png](data:image/png;base64,...)
#
# `qml.ctrl(qml.T, control=1, control_values=0)(wires=2)`
#
# * **control=1** - är wire där vita cirkeln connectar
# * **control_values=0** - 0 för vit, 1 för svart (tillstånd)
# * **wires=2** - är wire där T connectar

# %%
dev = qml.device("default.qubit", wires = 3)

@qml.qnode(dev)
def ctrl_circuit(theta,phi):
    """Implements the circuit shown in the Codercise statement
    Args:
        theta (float): Rotation angle for RX
        phi (float): Rotation angle for RY
    Returns:
        (numpy.array): The output state of the QNode
    """
    qml.RY(phi,wires=0)
    qml.Hadamard(wires=1)
    qml.RX(theta,wires=2)
    qml.ctrl(qml.S, control=0, control_values=1)(wires=1)
    qml.ctrl(qml.T, control=1, control_values=0)(wires=2)
    qml.ctrl(qml.Hadamard, control=2, control_values=1)(wires=0)



    return qml.state()
